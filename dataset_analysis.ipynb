# %%
from custom_torch_dataset import SwipeDataset
import os
from torch.utils.data import random_split

dataset_path = os.path.join(os.getcwd(), "dataset")

data = SwipeDataset(data_dir=dataset_path,
                    batch=True,
                    batch_first=True)

# %%
input_lengths = [x.shape[1] for x in data[:][0][:]]
max(input_lengths)
# Out:
# 349

# %%
import matplotlib.pyplot as plt

plt.hist(input_lengths, bins=30, edgecolor='black', alpha=0.7)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
word_lengths = [len(x) for x in data[:][1][:]]
max(word_lengths)
# Out:
# 15

# %%
import matplotlib.pyplot as plt

plt.hist(word_lengths, bins=15, edgecolor='black', alpha=0.7)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
